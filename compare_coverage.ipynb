# %%
import numpy as np
from snorkel.labeling import LFAnalysis
from snorkel.labeling import labeling_function

# %%
# define dummy labeling functions

@labeling_function()
def label_rp():
    pass

@labeling_function()
def label_wp():
    pass

@labeling_function()
def label_snopes():
    pass

@labeling_function()
def label_politifact():
    pass

@labeling_function()
def factcheckqa_sentiment():
    pass

@labeling_function()
def factcheckafpqa_sentiment():
    pass

@labeling_function()
def speaker():
    pass

# %%
lfs = [
    label_rp,
    label_wp,
    label_snopes,
    label_politifact,
    factcheckqa_sentiment,
    factcheckafpqa_sentiment,
    speaker,
]

# %%
# loading the matricies
L_train = np.load("./data/L_train.npy")
L_valid = np.load("./data/L_valid.npy")
Y_valid = np.load("./data/Y_valid.npy")
L_train_expanded = np.load("./data/L_train_expanded_llama.npy")
L_valid_expanded = np.load("./data/L_valid_expanded_llama.npy")

# %%
LFAnalysis(L=L_train, lfs=lfs).lf_summary()
# Out:
#                           j Polarity  Coverage  Overlaps  Conflicts
# label_rp                  0   [0, 1]  0.007970  0.006984   0.002219
# label_wp                  1   [0, 1]  0.009860  0.008874   0.003122
# label_snopes              2      [0]  0.027691  0.026952   0.004108
# label_politifact          3   [0, 1]  0.244618  0.184717   0.071159
# factcheckqa_sentiment     4   [0, 1]  0.020789  0.020049   0.010764
# factcheckafpqa_sentiment  5   [0, 1]  0.000822  0.000822   0.000493
# speaker                   6   [0, 1]  0.721282  0.216352   0.075842

# %%
LFAnalysis(L=L_train_expanded, lfs=lfs).lf_summary()
# Out:
#                           j Polarity  Coverage  Overlaps  Conflicts
# label_rp                  0   [0, 1]  0.007149  0.006081   0.001315
# label_wp                  1   [0, 1]  0.007970  0.006902   0.001808
# label_snopes              2      [0]  0.023172  0.022514   0.003698
# label_politifact          3   [0, 1]  0.225719  0.160477   0.043221
# factcheckqa_sentiment     4   [0, 1]  0.015366  0.014626   0.006409
# factcheckafpqa_sentiment  5   [0, 1]  0.000657  0.000657   0.000493
# speaker                   6   [0, 1]  0.684141  0.186935   0.046754

# %%
LFAnalysis(L_valid, lfs).lf_summary(Y_valid)
# Out:
#                           j Polarity  Coverage  Overlaps  Conflicts  Correct  \
# label_rp                  0   [0, 1]  0.007561  0.006903   0.003616       23
# label_wp                  1   [0, 1]  0.012492  0.012163   0.005588       38
# label_snopes              2      [0]  0.028271  0.026956   0.004274       77
# label_politifact          3   [0, 1]  0.241289  0.173899   0.062459      452
# factcheckqa_sentiment     4   [0, 1]  0.020053  0.018738   0.011177       37
# factcheckafpqa_sentiment  5   [0, 1]  0.001644  0.001644   0.000986        2
# speaker                   6   [0, 1]  0.704471  0.204142   0.067390     1644
#
#                           Incorrect  Emp. Acc.
# label_rp                          0   1.000000
# label_wp                          0   1.000000
# label_snopes                      9   0.895349
# label_politifact                282   0.615804
# factcheckqa_sentiment            24   0.606557
# factcheckafpqa_sentiment          3   0.400000
# ...

# %%
LFAnalysis(L_valid_expanded, lfs).lf_summary(Y_valid)
# Out:
#                           j Polarity  Coverage  Overlaps  Conflicts  Correct  \
# label_rp                  0   [0, 1]  0.006246  0.005588   0.002301       19
# label_wp                  1   [0, 1]  0.009533  0.009204   0.003287       29
# label_snopes              2      [0]  0.025970  0.024655   0.003287       70
# label_politifact          3   [0, 1]  0.223866  0.149901   0.036489      410
# factcheckqa_sentiment     4   [0, 1]  0.014135  0.012821   0.005588       25
# factcheckafpqa_sentiment  5   [0, 1]  0.001644  0.001644   0.000986        2
# speaker                   6   [0, 1]  0.667324  0.179158   0.040434     1512
#
#                           Incorrect  Emp. Acc.
# label_rp                          0   1.000000
# label_wp                          0   1.000000
# label_snopes                      9   0.886076
# label_politifact                271   0.602056
# factcheckqa_sentiment            18   0.581395
# factcheckafpqa_sentiment          3   0.400000
# ...
